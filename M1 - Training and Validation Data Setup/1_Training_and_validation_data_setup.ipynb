# %%
import nibabel as nib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_t1 = nib.load("data/IXI195-HH-1620-T1_fcm.nii.gz")
image_data_t1 = image_t1.get_fdata()

# %%
plt.imshow(image_data_t1[30, :, :],cmap="gray",origin="lower")

# %%
image_t2 = nib.load("data/IXI195-HH-1620-T2_reg_fcm.nii.gz")
image_data_t2 = image_t2.get_fdata()

# %%
plt.imshow(image_data_t2[:, 40, :],cmap="gray",origin="lower")
